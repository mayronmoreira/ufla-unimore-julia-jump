# %% [markdown]
# # On modelling optimization problems via Julia JuMP
#
# ## Prof. Mayron César O. Moreira
#
# **Universidade Federal de Lavras (UFLA)**
# **Department of Computer Science**
# **Lavras, Minas Gerais, Brazil**
#
# *Università degli Studi di Modena e Reggio Emilia (UNIMORE)*
# *Reggio Emilia, Italy*

# %% [markdown]
# ## On solving arc routing in Eulerian districts
#
# Consider a company that wants to plan routing activities in a city, for commercial proposals. The company aims at dividing streets into connected districts to avoid overloading of its teams. The number of business areas corresponds to the number of depots the company has. The main goal is to minimize the total distance traveled by workers assigned to its corresponding region, using the depot position as a reference point.
#
# In this notebook, we will work with García-Ayala et al. (2016) paper, that describes a variant of the previous arc routing problem such that the induced subgraph generated by the partitioning process must keep even degree of their vertices, keeping a percentage of Eulerian subgraphs. The idea of having Eulerian subgraphs is to avoid running the same edge twice and then, reduce "*deadhead time*." As follows, we show the **Figure extracted from García-Ayala et al. (2016)**, that shows unfavorable and favorable arc partitions.
#
# ![García-Ayala et al. (2016)](images/eulerian.png)

# %% [markdown]
# ### Mathematical model
# We present the mathematical model introduced by García-Ayala et al. (2016).
#
# * **Parameters**
#     * $G=(V,E)$: planar graph, $|V|=n$ and $|E|=m$, where $V$ represents street crossings or dead ends, and each edge corresponds to a street or a road.
#     * $e=(i,j) \in E$: each edge $e$ has a length $l_e \in \mathbb{R}_+$, and a demand $d_e \in \mathbb{R}_+$.
#     * $P=\{1,2,...,k\} \subset V$: set of depots.
#     * $\sigma(e)$: set of edges adjacent to $e$.
#     * $\sigma(S) \subset E$: cut set of $S$. The edge $e=(i,j) \in \sigma(S)$ if $i \in V\backslash V(S)$ and $j \in V(S)$, where $V(S)$ is the set of vertices associated with edges on $S$.
#     * $\delta(i) \subset E$: set of edges adjacent to $i \in V$.
#     * $\tilde{V} \subseteq V$: set of even degree vertices.
#     * $b_{pe} \in \mathbb{R}_+$: minimum distance from depot $p$ to edge $e=(i,j)$, given by $b_{pe} = \min\{f_{pi},f_{pj}\}$, where $f_{ij}$ is the shortest-path between $i$ and $j$ on $G$.
#     * $\overline{D} = \frac{\sum_{e \in E}d_e}{|P|}$: average demand per district.
#     * $\tau_1 \in (0,1)$: tolerance for demand balance constraints.
#     * $\tau_2 \in (0,1)$: tolerance for parity balance constraints.
#     * $M \in \mathbb{R}_+$: sufficient large constant.
#
#
# * **Solution**: $k$-partition of edges $(E_1,E_2,...,E_k)$ such that each district $(V(E_p),E_p)$ must meet technical criteria (mathematically exposed in the following). We take $V(E_p)$ as the set of vertices that are incident to at least one edge of $E_p$.

# %% [markdown]
# * **Parameters (Julia)**

# %%
include("codes/instanceAR.jl")

# Arc routing instance
fileInstance="instances/ar/Problem2.txt"

io=open(fileInstance)

instance = readAR(io)

n = instance.n
m = instance.m
k = instance.k
Edges = instance.E
E = Dict()

d = zeros(Float64, m)
for e in Edges
    d[e.id] = e.d
    E[e.i.id,e.j.id] = e.id
end

b = instance.b
sgmE = instance.sgmE # sigma(e)
delta = instance.delta
davg = instance.davg

V = collect(1:n)
P = collect(1:k)


# Sets of even and odd degree vertices
V_Even = [i for i in V if size(delta[i])[1] % 2 == 0]
V_Odd = [i for i in V if size(delta[i])[1] % 2 != 0]
                        
println(V_Even)
println(V_Odd)
println(P)

tau1 = 0.10
tau2 = 0.05
                        
M = size(maximum(delta))[1] # M is equal to the largest node degree
; # Disable output messages after the block
# Out:
# [1, 6, 10, 13, 14, 17, 19, 20, 21, 22, 24, 25, 27, 28]
# [2, 3, 4, 5, 7, 8, 9, 11, 12, 15, 16, 18, 23, 26]
# [1, 2, 3]

# %% [markdown]
# * **Drawing the graph**

# %%
#=
using GraphPlot, LightGraphs, Cairo, Fontconfig, Colors, Compose

g = Graph(n)

edgelabel = Array{Int64}(undef, m)
nodelabel = Array{Int64}(undef, n)

for i in 1:m
    add_edge!(g, Edges[i].i.id, Edges[i].j.id)
    edgelabel[i] = Edges[i].id
end

edgeColor = [colorant"grey", colorant"blue", colorant"orange", colorant"red", colorant"purple", colorant"darkred", colorant"cyan", colorant"magenta", colorant"darkblue", colorant"lightseagreen"]
colors = [colorant"grey" for i in  1:m]

for i in 1:n
    nodelabel[i]=i
end

draw(PNG("Grafo1.png", 20cm, 20cm), 
    gplot(g, edgestrokec=colors, edgelabel=edgelabel, nodelabel=nodelabel))
=#
# Out:
# ArgumentError: Package Cairo not found in current path:
# - Run `import Pkg; Pkg.add("Cairo")` to install the Cairo package.
#
#
# Stacktrace:
#  [1] require(::Module, ::Symbol) at .\loading.jl:823
#  [2] top-level scope at In[6]:1

# %% [markdown]
# * **OR libraries**

# %%
using JuMP
using Cbc

# %% [markdown]
# * **Mathematical model**

# %%
model = Model(with_optimizer(Cbc.Optimizer,seconds=60))
;

# %% [markdown]
# * **Variables**
#
#     * $x_{pe} \in \{0,1\}$: equal to one if edge $e \in E$ is assigned to district $p \in P$.
#     * $w_{pi} \in \{0,1\}$: equal to one if vertex $i \in V$ is incident to an edge assigned to district $p \in P$.
#     * $z^{O}_{ip} \in \{0,1\}$: equal to one if the degree of vertex $i \in V$ in district $p \in P$ is odd.
#     * $z_{ip} \in \mathbb{Z}_+$: auxiliary variable related to variable $z^{O}_{ip}$.
#     * $r_i \in \{0,1\}$: equal to one if vertex $i \in \tilde{V}$ looses parity.

# %%
@variable(model, x[P,1:m], Bin)
@variable(model, w[P,V], Bin)
@variable(model, zo[V,P], Bin)
@variable(model, z[V,P] >= 0, Int)
@variable(model, r[V], Bin)
;

# %% [markdown]
# * **Objective function**: minimize sum of distances to and from each edge assigned to the depot. With this function, the authors try to obtain compact districts.
#
# \begin{equation}
# \min \sum_{p \in P}\sum_{e \in E} b_{pe}x_{pe}
# \end{equation}

# %%
@objective(model, Min, sum(b[p,e]*x[p,e] for p=1:k, e=1:m))
;

# %% [markdown]
# * **Constraint**: each edge must be assigned to a district.
#
# \begin{equation}
# \sum_{p \in P}x_{pe} = 1 \quad \forall e \in E
# \end{equation}

# %%
@constraint(model, [e=1:m], sum(x[p,e] for p in P) == 1)
;

# %% [markdown]
# * **Constraint**: district contiguity.
#
# \begin{equation}
# \sum_{s \in \sigma(S)} x_{ps} - \sum_{s \in S} x_{ps} \ge x_{pe} - |S| \quad \forall p \in P, \forall e \in E,  S \subset E \backslash \sigma(e)
# \end{equation}
#
# Here we have an exponential number of constraints. To cope with that, García-Ayala et al. (2016) eliminate these constraints and solve the model without them. In the sequence, they add iteratively contiguity cuts identified by a BFS on each district. We will see this in this notebook.

# %% [markdown]
# * **Constraint**: balance districts within a tolerance $\tau_1$.
#
# \begin{equation}
# \sum_{i \in E}d_ex_{pe} \ge (1-\tau_1)\overline{D} \quad \forall p \in P
# \end{equation}
#
# \begin{equation}
# \sum_{i \in E}d_ex_{pe} \le (1+\tau_1)\overline{D} \quad \forall p \in P
# \end{equation}

# %%
@constraint(model, [p in P], sum(d[e]*x[p,e] for e=1:m) >= (1-tau1)*davg)
@constraint(model, [p in P], sum(d[e]*x[p,e] for e=1:m) <= (1+tau1)*davg)
# Alternatively
#@constraint(model, [p in P], (1-tau1)*davg <= sum(d[e]*x[p,e] for e in E) <= (1+tau1)*davg)
#
;

# %% [markdown]
# * **Constraint**: coupling constraints between variables $x$ and $w$.
#
# \begin{equation}
# \sum_{i \in E}\sum_{e \in \delta(i)} x_{pe} \le Mw_{pi} \quad \forall p \in P, \forall i in V
# \end{equation}
#
# \begin{equation}
# \sum_{i \in E} w_{pi} \le \sum_{e \in \delta(i)} x_{pe} \quad \forall p \in P, \forall i in V
# \end{equation}

# %%
@constraint(model, [p in P, i in V], sum(x[p,e] for e in delta[i]) <= M*w[p,i])
@constraint(model, [p in P, i in V], w[p,i] <= sum(x[p,e] for e in delta[i]))
;

# %% [markdown]
# * **Constraint**: detect if a vertex $i$ has an odd degree in the partition $p$.
#
# \begin{equation}
# \sum_{e \in \delta(i)}x_{pe} = 2z_{ip} + z^{O}_{ip} \quad \forall p \in P, \forall i \in V
# \end{equation}

# %%
@constraint(model, [p in P, i in V], sum(x[p,e] for e in delta[i]) == 2*z[i,p] + zo[i,p])
;

# %% [markdown]
# * **Constraint**: limitation of imparity gain.
#
# \begin{equation}
# r_i \le \sum_{p \in P} z^{O}_{ip} \quad \forall i \in \tilde{V}
# \end{equation}
#
# \begin{equation}
# |P|r_i \ge \sum_{p \in P} z^{O}_{ip} \quad \forall i \in V
# \end{equation}
#
# \begin{equation}
# r_i \le \sum_{p \in P} z^{O}_{ip} - 1 \quad \forall i \in V \backslash \tilde{V}
# \end{equation}
#
# \begin{equation}
# |P|r_i \ge \sum_{p \in P} z^{O}_{ip} - 1 \quad \forall i \in V \backslash \tilde{V}
# \end{equation}
#
# \begin{equation}
# \frac{1}{|V|}\sum_{i \in V}r_i \le \tau_2
# \end{equation}

# %%
@constraint(model, [i in V_Even], r[i] <= sum(zo[i,p] for p in P))
@constraint(model, [i in V_Even], k*r[i] >= sum(zo[i,p] for p in P))
@constraint(model, [i in V_Odd], r[i] <= sum(zo[i,p] for p in P) - 1)
@constraint(model, [i in V_Odd], k*r[i] >= sum(zo[i,p] for p in P) - 1)
@constraint(model, (1.0/n)*sum(r[i] for i in V) <= tau2)
;

# %% [markdown]
# * **Running the model**

# %%
optimize!(model)
;
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.9.9
# Build Date: Dec 31 2018
#
# command line - Cbc_C_Interface -seconds 60 -solve -quit (default strategy 1)
# seconds was changed from 1e+100 to 60
# Continuous objective value is 7305.73 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 13 strengthened rows, 0 substitutions
# Cgl0004I processed model has 359 rows, 421 columns (421 integer (388 of which binary)) and 1729 elements
# Cbc0038I Initial state - 65 integers unsatisfied sum - 28.4093
# Cbc0038I Pass   1: suminf.   27.73877 (61) obj. 7305.73 iterations 76
# Cbc0038I Pass   2: suminf.   23.14977 (51) obj. 7314.85 iterations 16
# Cbc0038I Pass   3: suminf.   23.14977 (51) obj. 7314.85 iterations 4
# Cbc0038I Pass   4: suminf.   21.14977 (47) obj. 7314.85 iterations 9
# Cbc0038I Pass   5: suminf.   21.14977 (47) obj. 7314.85 iterations 4
# Cbc0038I Pass   6: suminf.   19.14977 (43) obj. 7314.85 iterations 8
# Cbc0038I Pass   7: suminf.   19.14977 (43) obj. 7314.85 iterations 4
# Cbc0038I Pass   8: suminf.   16.64977 (38) obj. 7314.85 iterations 9
# Cbc0038I Pass   9: suminf.   16.64977 (38) obj. 7314.85 iterations 3
# Cbc0038I Pass  10: suminf.   16.26209 (38) obj. 7314.85 iterations 17
# Cbc0038I Pass  11: suminf.   16.23877 (38) obj. 7305.73 iterations 19
# Cbc0038I Pass  12: suminf.   15.85093 (34) obj. 7320.34 iterations 11
# Cbc0038I Pass  13: suminf.   10.00000 (20) obj. 7430.19 iterations 18
# Cbc0038I Pass  14: suminf.   10.00000 (20) obj. 7430.19 iterations 4
# Cbc0038I Pass  15: suminf.   10.00000 (20) obj. 7430.19 iterations 6
# Cbc0038I Pass  16: suminf.   17.85000 (38) obj. 8842.29 iterations 91
# Cbc0038I Pass  17: suminf.   17.50000 (37) obj. 8842.29 iterations 36
# Cbc0038I Pass  18: suminf.   14.55000 (31) obj. 8842.29 iterations 11
# Cbc0038I Pass  19: suminf.   14.55000 (31) obj. 8842.29 iterations 5
# Cbc0038I Pass  20: suminf.   14.85000 (32) obj. 8842.29 iterations 7
# Cbc0038I Pass  21: suminf.   14.50000 (31) obj. 8842.29 iterations 5
# Cbc0038I Pass  22: suminf.   14.55000 (31) obj. 8842.29 iterations 4
# Cbc0038I Pass  23: suminf.   14.70155 (40) obj. 8841.23 iterations 79
# Cbc0038I Pass  24: suminf.   13.42197 (38) obj. 8843.55 iterations 55
# Cbc0038I Pass  25: suminf.   13.45853 (33) obj. 8862.68 iterations 9
# Cbc0038I Pass  26: suminf.   13.45853 (33) obj. 8862.68 iterations 1
# Cbc0038I Pass  27: suminf.   11.45853 (29) obj. 8862.68 iterations 11
# Cbc0038I Pass  28: suminf.   11.45853 (29) obj. 8862.68 iterations 3
# Cbc0038I Pass  29: suminf.    9.93333 (21) obj. 9098.57 iterations 17
# Cbc0038I Pass  30: suminf.    9.93333 (21) obj. 9098.57 iterations 5
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 283 integers at bound fixed and 0 continuous of which 11 were internal integer and 0 internal continuous
# Cbc0038I Mini branch and bound did not improve solution (0.04 seconds)
# Cbc0038I After 0.04 seconds - Feasibility pump exiting - took 0.02 seconds
# Cbc0031I 47 added rows had average density of 33.042553
# Cbc0013I At root node, 47 cuts changed objective from 7305.7322 to 7575.0252 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 539 row cuts average 2.0 elements, 0 column cuts (19 active)  in 0.140 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 1062 row cuts average 234.3 elements, 0 column cuts (0 active)  in 1.081 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 298 row cuts average 2.7 elements, 0 column cuts (0 active)  in 0.158 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.004 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 116 row cuts average 16.8 elements, 0 column cuts (0 active)  in 0.225 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.044 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 365 row cuts average 55.8 elements, 0 column cuts (0 active)  in 0.093 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, 1e+50 best solution, best possible 7575.0252 (2.47 seconds)
# Cbc0012I Integer solution of 7763.889 found by DiveCoefficient after 3904 iterations and 9 nodes (2.98 seconds)
# Cbc0038I Full problem 359 rows 421 columns, reduced to 0 rows 0 columns
# Cbc0038I Full problem 359 rows 421 columns, reduced to 39 rows 31 columns
# Cbc0004I Integer solution of 7745.3994 found after 5174 iterations and 60 nodes (3.23 seconds)
# Cbc0016I Integer solution of 7702.8672 found by strong branching after 6305 iterations and 81 nodes (3.42 seconds)
# Cbc0038I Full problem 359 rows 421 columns, reduced to 39 rows 33 columns
# Cbc0016I Integer solution of 7693.6484 found by strong branching after 6610 iterations and 92 nodes (3.48 seconds)
# Cbc0012I Integer solution of 7684.5967 found by DiveCoefficient after 7527 iterations and 113 nodes (3.57 seconds)
# Cbc0001I Search completed - best objective 7684.596742378053, took 8182 iterations and 118 nodes (3.79 seconds)
# Cbc0032I Strong branching done 1492 times (23165 iterations), fathomed 13 nodes and fixed 7 variables
# Cbc0035I Maximum depth 20, 1309 variables fixed on reduced cost
# Cuts at root node changed objective from 7305.73 to 7575.03
# Probing was tried 189 times and created 1941 cuts of which 19 were active after adding rounds of cuts (0.186 seconds)
# Gomory was tried 186 times and created 1077 cuts of which 0 were active after adding rounds of cuts (1.125 seconds)
# Knapsack was tried 186 times and created 549 cuts of which 0 were active after adding rounds of cuts (0.262 seconds)
# Clique was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.004 seconds)
# MixedIntegerRounding2 was tried 186 times and created 207 cuts of which 0 were active after adding rounds of cuts (0.258 seconds)
# FlowCover was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.044 seconds)
# TwoMirCuts was tried 186 times and created 731 cuts of which 0 were active after adding rounds of cuts (0.188 seconds)
# ImplicationCuts was tried 79 times and created 387 cuts of which 0 were active after adding rounds of cuts (0.017 seconds)
#
# Result - Optimal solution found
#
# Objective value:                7684.59674238
# Enumerated nodes:               118
# Total iterations:               8182
# Time (CPU seconds):             3.81
# Time (Wallclock seconds):       3.81
#
# Total time (CPU seconds):       3.81   (Wallclock seconds):       3.81

# %% [markdown]
# * **Depth-First Search (DFS) to identify components**
#
#     * Parameters:
#         * $(i)$: graph
#         * $(ii)$: district id
#         * $(iii)$: set of vertices
#
# For further informations, see (*Cormen, T. H., Leiserson, C. E., Rivest, R. L., & Stein, C. (2009). Introduction to algorithms. Chap. 22. MIT press.*)

# %%
function DFS(g, p, setVertices)
    visited = [false for _ in V]
    components = Vector{SimpleDiGraph{Int64}}()
    
    for v in setVertices[p]
        if(!visited[v])
            #=
            The function dfs_tree returns a tree, not necessarily a forest.
            =#
            T = dfs_tree(g[p], v) 
            for e in collect(edges(T))
                visited[src(e)] = visited[dst(e)] = true
            end
            push!(components, T)
        end
    end
    
    return components
end
# Out:
# DFS (generic function with 1 method)

# %% [markdown]
# * **(i) Obtaining the results, (ii) testing if the districts are connected, and  (iii) obtaining the cuts**

# %%
## Part (i)

startTime = 0
endTime = 120
while(endTime - startTime >= 0)
    # First, we test if the solution respects conectivity.
    vtxSol = [Vector{Int}() for _ in P]
    edgSol = [Vector{Int}() for _ in P]

    # Create subgraphs of districts
    g = [Graph(n) for p in P]

    for p in P
        for e=1:m
            if(JuMP.value(x[p,e]) >= 0.9)
                add_edge!(g[p], Edges[e].i.id, Edges[e].j.id)

                push!(edgSol[p], e)
                i = Edges[e].i.id
                j = Edges[e].j.id

                # Avoiding repeated items
                if(!(i in vtxSol[p]))
                    push!(vtxSol[p], i)
                end
                if(!(j in vtxSol[p]))
                    push!(vtxSol[p], j)
                end
            end
        end

        # For convenience
        vtxSol[p] = sort(vtxSol[p])
    end

    ##########################

    ## Part (ii)

    finish = true
    for p in P
        components = DFS(g, p, vtxSol)
        numberComp = size(components)[1]
        
        # Then we calculate how the sets S and CutSet will be composed
        println("numberComp = ", numberComp)
        
        if(numberComp > 0)
            finish = false
            # Get the set S
            for c1 in components
                S = Vector{Int}()
                VtxS = Vector{Int}()
                CutSet = Vector{Int}()
            
                edgs = collect(edges(c1))

                for e in edgs
                    if(src(e) < dst(e))
                        push!(S, E[src(e), dst(e)])
                    else
                        push!(S, E[dst(e), src(e)])
                    end
                    
                    if(!(src(e) in VtxS))
                        push!(VtxS, src(e))
                    end
                    
                    if(!(dst(e) in VtxS))
                        push!(VtxS, dst(e))
                    end
                        
                end
                               
                # Calculating CutSet
                for v in VtxS
                    edgs = delta[v] # All edges incident in v
                    for e in edgs
                        if(!(Edges[e].i.id in VtxS && Edges[e].j.id in VtxS))
                            push!(CutSet, e)
                        end
                    end
                end
                
                #println("CutSet = ", CutSet)
                #println("-----------------")
                
                @constraint(model, sum(x[p,s] for s in CutSet) 
                    - sum(x[p,s] for s in S) >= -1*(size(S)[1] - 1))
            end
        end
    end
    
    if(finish)
        break
    end
    
    # Running model again
    optimize!(model)
    
    startTime = time()
end
# Out:
# numberComp = 4
# numberComp = 2
# numberComp = 3
# Welcome to the CBC MILP Solver
# Version: 2.9.9
# Build Date: Dec 31 2018
#
# command line - Cbc_C_Interface -seconds 60 -solve -quit (default strategy 1)
# seconds was changed from 1e+100 to 60
# Continuous objective value is 7415.66 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 22 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 4 strengthened rows, 0 substitutions
# Cgl0004I processed model has 368 rows, 421 columns (421 integer (388 of which binary)) and 1866 elements
# Cbc0038I Initial state - 97 integers unsatisfied sum - 36.6953
# Cbc0038I Pass   1: suminf.   27.83333 (60) obj. 7463.56 iterations 78
# Cbc0038I Pass   2: suminf.   27.16667 (58) obj. 7463.56 iterations 15
# Cbc0038I Pass   3: suminf.   23.16667 (50) obj. 7463.56 iterations 18
# Cbc0038I Pass   4: suminf.   23.16667 (50) obj. 7463.56 iterations 3
# Cbc0038I Pass   5: suminf.   19.16667 (42) obj. 7463.56 iterations 14
# Cbc0038I Pass   6: suminf.   19.16667 (42) obj. 7463.56 iterations 3
# Cbc0038I Pass   7: suminf.   14.00000 (28) obj. 7556.41 iterations 22
# Cbc0038I Pass   8: suminf.   14.00000 (28) obj. 7556.41 iterations 10
# Cbc0038I Pass   9: suminf.   14.00000 (28) obj. 7556.41 iterations 6
# Cbc0038I Pass  10: suminf.   23.70000 (52) obj. 8119.3 iterations 94
# Cbc0038I Pass  11: suminf.   21.50000 (44) obj. 7986.81 iterations 46
# Cbc0038I Pass  12: suminf.   18.50000 (38) obj. 7986.81 iterations 24
# Cbc0038I Pass  13: suminf.   18.50000 (38) obj. 7986.81 iterations 19
# Cbc0038I Pass  14: suminf.   18.50000 (38) obj. 7986.81 iterations 13
# Cbc0038I Pass  15: suminf.   23.28793 (53) obj. 9432.85 iterations 100
# Cbc0038I Pass  16: suminf.   22.96412 (51) obj. 9433.26 iterations 61
# Cbc0038I Pass  17: suminf.   22.96412 (51) obj. 9433.26 iterations 1
# Cbc0038I Pass  18: suminf.   18.96412 (43) obj. 9433.26 iterations 18
# Cbc0038I Pass  19: suminf.   18.96412 (43) obj. 9433.26 iterations 7
# Cbc0038I Pass  20: suminf.   25.51792 (61) obj. 10290.4 iterations 103
# Cbc0038I Pass  21: suminf.   24.73757 (57) obj. 10290.4 iterations 75
# Cbc0038I Pass  22: suminf.   20.39956 (46) obj. 10248 iterations 31
# Cbc0038I Pass  23: suminf.   20.39956 (46) obj. 10248 iterations 19
# Cbc0038I Pass  24: suminf.   20.76667 (42) obj. 10244.9 iterations 37
# Cbc0038I Pass  25: suminf.   20.76667 (42) obj. 10244.9 iterations 15
# Cbc0038I Pass  26: suminf.   20.43333 (42) obj. 10244.9 iterations 15
# Cbc0038I Pass  27: suminf.   20.43333 (42) obj. 10244.9 iterations 12
# Cbc0038I Pass  28: suminf.   20.76667 (42) obj. 10244.9 iterations 12
# Cbc0038I Pass  29: suminf.   25.50000 (54) obj. 10173.1 iterations 89
# Cbc0038I Pass  30: suminf.   25.33333 (52) obj. 10173.1 iterations 66
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 179 integers at bound fixed and 0 continuous of which 3 were internal integer and 0 internal continuous
# Cbc0038I Mini branch and bound did not improve solution (0.05 seconds)
# Cbc0038I After 0.05 seconds - Feasibility pump exiting - took 0.03 seconds
# Cbc0031I 46 added rows had average density of 47.521739
# Cbc0013I At root node, 46 cuts changed objective from 7415.662 to 7647.7317 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 408 row cuts average 2.0 elements, 0 column cuts (15 active)  in 0.129 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 1155 row cuts average 225.6 elements, 0 column cuts (0 active)  in 0.951 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 196 row cuts average 2.4 elements, 0 column cuts (0 active)  in 0.138 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.004 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 115 row cuts average 26.7 elements, 0 column cuts (0 active)  in 0.141 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.037 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 389 row cuts average 63.6 elements, 0 column cuts (0 active)  in 0.094 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, 1e+50 best solution, best possible 7647.7317 (2.19 seconds)
# Cbc0016I Integer solution of 8983.6572 found by strong branching after 5057 iterations and 40 nodes (3.10 seconds)
# Cbc0038I Full problem 368 rows 421 columns, reduced to 91 rows 75 columns
# Cbc0016I Integer solution of 8018.3888 found by strong branching after 5901 iterations and 61 nodes (3.28 seconds)
# Cbc0016I Integer solution of 7856.3468 found by strong branching after 6049 iterations and 63 nodes (3.31 seconds)
# Cbc0004I Integer solution of 7809.7566 found after 6950 iterations and 76 nodes (3.44 seconds)
# Cbc0004I Integer solution of 7726.8401 found after 7296 iterations and 84 nodes (3.51 seconds)
# Cbc0038I Full problem 368 rows 421 columns, reduced to 101 rows 73 columns
# Cbc0012I Integer solution of 7692.1891 found by DiveCoefficient after 8362 iterations and 108 nodes (3.65 seconds)
# Cbc0001I Search completed - best objective 7692.189064393154, took 8964 iterations and 114 nodes (3.76 seconds)
# Cbc0032I Strong branching done 1764 times (24622 iterations), fathomed 8 nodes and fixed 6 variables
# Cbc0035I Maximum depth 18, 1208 variables fixed on reduced cost
# Cuts at root node changed objective from 7415.66 to 7647.73
# Probing was tried 215 times and created 2377 cuts of which 15 were active after adding rounds of cuts (0.176 seconds)
# Gomory was tried 213 times and created 1335 cuts of which 0 were active after adding rounds of cuts (1.015 seconds)
# Knapsack was tried 213 times and created 799 cuts of which 0 were active after adding rounds of cuts (0.277 seconds)
# Clique was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.004 seconds)
# MixedIntegerRounding2 was tried 213 times and created 281 cuts of which 0 were active after adding rounds of cuts (0.196 seconds)
# FlowCover was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.037 seconds)
# TwoMirCuts was tried 213 times and created 677 cuts of which 0 were active after adding rounds of cuts (0.137 seconds)
# ImplicationCuts was tried 71 times and created 343 cuts of which 0 were active after adding rounds of cuts (0.014 seconds)
#
# Result - Optimal solution found
#
# Objective value:                7692.18906439
# Enumerated nodes:               114
# Total iterations:               8964
# Time (CPU seconds):             3.78
# Time (Wallclock seconds):       3.78
#
# Total time (CPU seconds):       3.78   (Wallclock seconds):       3.78

# %% [markdown]
# * **Printing the graph**

# %%
g = Graph(n)

edgelabel = Array{Int64}(undef, m)
nodelabel = Array{Int64}(undef, n)

for i in 1:m
    add_edge!(g, Edges[i].i.id, Edges[i].j.id)
    edgelabel[i] = Edges[i].id
end

edgeColor = [colorant"grey", colorant"blue", colorant"orange", colorant"red", colorant"purple", colorant"darkred", colorant"cyan", colorant"magenta", colorant"darkblue", colorant"lightseagreen"]
colors = [colorant"grey" for i in  1:m]

edgesByDistrict = Vector{Vector{Int}}()
for p=1:k
    vectorAux = Vector{Int}()
    for e=1:m
        if(JuMP.value(x[p,e]) >= 0.9)
            push!(vectorAux, e)
        end
    end
    push!(edgesByDistrict, vectorAux)
end

for p in 1:k
    for j in 1:size(edgesByDistrict[p])[1]
        colors[edgesByDistrict[p][j]] = edgeColor[p + 1]
    end
end

for i in 1:n
    nodelabel[i]=i
end

draw(PNG("Grafo1.png", 20cm, 20cm), 
    gplot(g, edgestrokec=colors, edgelabel=edgelabel, nodelabel=nodelabel))

# %% [markdown]
# We could also implement this algorithm using *lazy constraints* through *callbacks*, to eliminate disconnected districts. To see an example of how this approach works in JuMP 0.18, see http://www.juliaopt.org/JuMP.jl/v0.12/callbacks.html.

# %% [markdown]
# ## References

# %% [markdown]
# García‐Ayala, G., González‐Velarde, J. L., Ríos‐Mercado, R. Z., & Fernández, E. (2016). A novel model for arc territory design: promoting Eulerian districts. International Transactions in Operational Research, 23(3), 433-458.
